# %% [markdown]
# # WeatherPy
# ----
#
# * Based on the analysis below comparing maximum temperature and latitude, the points form a parabolic shape with a local maximum between 0 to 20 degrees latitude (depending on the randomly generated cities). This means that as you approach the equator (i.e. when latitude approaches 0 degrees), the temperature increases, while as you move further away from the equator, the temperature decreases.
#
#
# * In investigating cloudiness and latitude, there is increased cloudiness around the equator with multiple cities near 0 degrees latitude having approx. 100% cloudiness. This trend matches NASA's Earth Observatory findings saying that there is a narrow strip near the equator where the skies are most likely to be cloudy. This is due to large scale circulation patterns in the tropics (https://earthobservatory.nasa.gov/images/85843/cloudy-earth).
#
#
# * When it comes to humidity and wind speed around the equator, humidity is rather high (i.e. clustered between 80 to 100%) and wind speed is minimal (i.e. under 20mph with most cities clustered around 0 to 10mph). While the majority of data points for humidity and wind speed against latitude are similar (i.e. with humidity, most points are above 50% humidity and with wind speed, most  points are below 15mph), as you move further away from the equator, there are more outliers (i.e. lower humidity percentages and higher wind speeds).

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import time
import csv

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# %%
# Import OpenWeather API wrapper
import openweathermapy as owm

# Create settings dictionary with correct unit mesure and api id
settings = {"units": "imperial", "appid": api_key}

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Randomly generate 2000 numbers between -90 and 90 for latitude
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
# Randomly generate 2000 numbers between -180 and 180 for longitude
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
# Create a set of random lat and lng combinations
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination using citipy
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    # Capitalize the city name
    city = city.title()
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 757

# %%
# Create a function called set_lists which seperates a list (lst) into smaller lists of n elements
def set_lists(lst, n):
    # For item i in the range from 0 to the length of lst,
    for i in range(0, len(lst),n):
        # Create an index range for lst with only n items
        yield lst[i:i+n]

# %%
cities_set = list(set_lists(cities,50))

# %% [markdown]
# ## Perform API Calls

# %%
# Create summary of desired weather details 
summary = ["name", "clouds.all","sys.country","dt","main.humidity","coord.lat","coord.lon","main.temp_max","wind.speed"]
# Create an empty list to append all summary details for each city
city_weather = []

# Initialize record number and set number
record_num = 1
set_num = 1

print("Beginning Data Retrieval")
print("-----------------------------")
# Using a for-loop,...
for city in cities:
    try:
        # If there are less than 50 records,... 
        if record_num <= 50:
            # Get current weather with correct settings dictionary and summary of desired weather details
            weather_info = owm.get_current(city, **settings)(*summary)
            # Add weather_info to the list of city_weather
            city_weather.append(weather_info)
            # Print the following statement to display the retrieval process
            print(f"Processing Record {record_num} of set {set_num} | {city}")
            # Increase the record number by 1 
            record_num = record_num + 1
        else:
            # Reset the record number to 1
            record_num = 1
            # Increase the set number by 1 once there are more than 50 records
            set_num = set_num + 1
    # Handle the exception i.e. missing city in the API
    except :
        # Print the following statement to display missing city
        print ("City not found. Skipping...")
print("-----------------------------")
print("Data Retrieval Complete  ")  
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of set 1 | Senekal
# Processing Record 2 of set 1 | Miramar
# Processing Record 3 of set 1 | Ushuaia
# Processing Record 4 of set 1 | Saint-Philippe
# Processing Record 5 of set 1 | Cape Town
# Processing Record 6 of set 1 | Kavaratti
# City not found. Skipping...
# Processing Record 7 of set 1 | New Norfolk
# Processing Record 8 of set 1 | Port Alfred
# Processing Record 9 of set 1 | Stephenville
# City not found. Skipping...
# Processing Record 10 of set 1 | Hermanus
# City not found. Skipping...
# Processing Record 11 of set 1 | Bambous Virieux
# City not found. Skipping...
# Processing Record 12 of set 1 | Henties Bay
# Processing Record 13 of set 1 | Rikitea
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 14 of set 1 | Punta Arenas
# Processing Record 15 of set 1 | Port Elizabeth
# Processing Record 16 of set 1 | Bilibino
# Processing Record 17 of set 1 | Taoudenni
# Processing Record 18 of set 1 | San Joaquin
# Processing Record 19 of set 1 | Busselton
# Processing Record 20 of set 1 | Carnarvon
# Processing Record 21 of set 1 | Albany
# Processing Record 22 of set 1 | Hithadhoo
# Processing Record 23 of set 1 | Nikolskoye
# Processing Record 24 of set 1 | Acajutla
# City not found. Skipping...
# Processing Record 25 of set 1 | Castro
# Processing Record 26 of set 1 | Bredasdorp
# Processing Record 27 of set 1 | Kavieng
# Processing Record 28 of set 1 | Ponta Do Sol
# City not found. Skipping...
# Processing Record 29 of set 1 | Sao Filipe
# Processing Record 30 of set 1 | Alice Springs
# City not found. Skipping...
# Processing Record 31 of set 1 | East London
# Processing Record 32 of set 1 | Praia Da Vitoria
# Processing Record 33 of set 1 | Beloha
# City not found. Skipping...
# Processing Record 34 of set 1 | Kikwit
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 35 of set 1 | Hambantota
# Processing Record 36 of set 1 | Changli
# Processing Record 37 of set 1 | Hamilton
# Processing Record 38 of set 1 | Saint George
# Processing Record 39 of set 1 | Jamestown
# Processing Record 40 of set 1 | Hobart
# Processing Record 41 of set 1 | Goundam
# Processing Record 42 of set 1 | Dunmore Town
# Processing Record 43 of set 1 | Byron Bay
# Processing Record 44 of set 1 | Sao Joao Da Barra
# Processing Record 45 of set 1 | Grindavik
# Processing Record 46 of set 1 | Mataura
# Processing Record 47 of set 1 | Jacareacanga
# Processing Record 48 of set 1 | Faanui
# Processing Record 49 of set 1 | Hilo
# Processing Record 50 of set 1 | Avarua
# Processing Record 1 of set 2 | Teya
# Processing Record 2 of set 2 | Lorengau
# Processing Record 3 of set 2 | Kodiak
# Processing Record 4 of set 2 | Wageningen
# Processing Record 5 of set 2 | Thinadhoo
# Processing Record 6 of set 2 | Vaini
# Processing Record 7 of set 2 | Havelock
# City not found. Skipping...
# Processing Record 8 of set 2 | Kapaa
# Processing Record 9 of set 2 | Cravo Norte
# City not found. Skipping...
# Processing Record 10 of set 2 | Atuona
# Processing Record 11 of set 2 | Cabo San Lucas
# Processing Record 12 of set 2 | Thompson
# Processing Record 13 of set 2 | Esperance
# Processing Record 14 of set 2 | Virginia Beach
# Processing Record 15 of set 2 | Broome
# Processing Record 16 of set 2 | Buenos Aires
# Processing Record 17 of set 2 | Butaritari
# Processing Record 18 of set 2 | Coquimbo
# Processing Record 19 of set 2 | Kahului
# Processing Record 20 of set 2 | Mar Del Plata
# Processing Record 21 of set 2 | Lebu
# Processing Record 22 of set 2 | Ribeira Grande
# Processing Record 23 of set 2 | Ahipara
# Processing Record 24 of set 2 | Mirnyy
# Processing Record 25 of set 2 | Mahebourg
# Processing Record 26 of set 2 | Mackay
# Processing Record 27 of set 2 | Lavrentiya
# Processing Record 28 of set 2 | Najran
# Processing Record 29 of set 2 | Olutanga
# Processing Record 30 of set 2 | Provideniya
# Processing Record 31 of set 2 | Knyaginino
# Processing Record 21 of set 5 | Moron
# Processing Record 22 of set 5 | Peniche
# Processing Record 23 of set 5 | Ombessa
# Processing Record 24 of set 5 | Kemin
# Processing Record 25 of set 5 | Victoria
# Processing Record 26 of set 5 | Fort Nelson
# Processing Record 27 of set 5 | Norman Wells
# Processing Record 28 of set 5 | Jacqueville
# City not found. Skipping...
# Processing Record 29 of set 5 | San Carlos De Bariloche
# Processing Record 30 of set 5 | Bethel
# Processing Record 31 of set 5 | Iwanai
# Processing Record 32 of set 5 | Balikpapan
# Processing Record 33 of set 5 | Ostrovnoy
# Processing Record 34 of set 5 | San Alberto
# Processing Record 35 of set 5 | Minsk
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 36 of set 5 | Waipawa
# Processing Record 37 of set 5 | Ambon
# Processing Record 38 of set 5 | Sao Luis Do Quitunde
# Processing Record 39 of set 5 | Kholtoson
# Processing Record 40 of set 5 | Erenhot
# Processing Record 41 of set 5 | Daud Khel
# Processing Record 42 of set 5 | Okhotsk
# Processing Record 43 of set 5 | Abu Samrah
# City not found. Skipping...
# Processing Record 44 of set 5 | Evensk
# Processing Record 45 of set 5 | Poya
# Processing Record 46 of set 5 | Caloundra
# Processing Record 47 of set 5 | Namie
# Processing Record 48 of set 5 | Darhan
# Processing Record 49 of set 5 | Mayya
# Processing Record 50 of set 5 | Aasiaat
# Processing Record 1 of set 6 | Sharanga
# Processing Record 2 of set 6 | Banda Aceh
# Processing Record 3 of set 6 | Comodoro Rivadavia
# Processing Record 4 of set 6 | Tocopilla
# Processing Record 5 of set 6 | Popondetta
# Processing Record 6 of set 6 | Alofi
# Processing Record 7 of set 6 | Iranshahr
# Processing Record 8 of set 6 | Samarai
# Processing Record 9 of set 6 | Chuy
# Processing Record 10 of set 6 | Naze
# Processing Record 11 of set 6 | Hasaki
# Processing Record 12 of set 6 | Vestmannaeyjar
# City not found. Skipping...
# Processing Record 13 of set 6 | Dolores
# Processing Record 14 of set 6 | Bud
# Processing Record 15 of set 6 | Vila Velha
# Processing Record 16 of set 6 | Osorio
# Processing Record 17 of set 6 | Dubasari
# Processing Record 18 of set 6 | Usinsk
# Processing Record 19 of set 6 | Ginir
# Processing Record 20 of set 6 | Porto Novo
# City not found. Skipping...
# Processing Record 21 of set 6 | Le Port
# Processing Record 22 of set 6 | Brigantine
# Processing Record 23 of set 6 | Kombissiri
# Processing Record 24 of set 6 | Ketchikan
# Processing Record 25 of set 6 | Punta Alta
# Processing Record 26 of set 6 | Quatre Cocos
# Processing Record 27 of set 6 | San-Pedro
# Processing Record 28 of set 6 | San Andres
# Processing Record 29 of set 6 | Chakulia
# Processing Record 30 of set 6 | Yerofey Pavlovich
# City not found. Skipping...
# Processing Record 31 of set 6 | Iralaya
# Processing Record 32 of set 6 | Ugoofaaru
# Processing Record 33 of set 6 | Great Falls
# Processing Record 34 of set 6 | Jumla
# Processing Record 35 of set 6 | Juntas
# Processing Record 36 of set 6 | Sayyan
# Processing Record 37 of set 6 | Leshukonskoye
# Processing Record 38 of set 6 | Nome
# Processing Record 39 of set 6 | Yar-Sale
# Processing Record 40 of set 6 | North Bend
# Processing Record 41 of set 6 | Talnakh
# Processing Record 42 of set 6 | Akdepe
# Processing Record 43 of set 6 | Ridgecrest
# Processing Record 44 of set 6 | Huarmey
# Processing Record 45 of set 6 | Naryan-Mar
# Processing Record 46 of set 6 | Acapulco
# City not found. Skipping...
# Processing Record 47 of set 6 | Ngunguru
# Processing Record 48 of set 6 | Hami
# Processing Record 49 of set 6 | Jos
# Processing Record 50 of set 6 | Trinidad
# Processing Record 1 of set 7 | Kerema
# Processing Record 2 of set 7 | Tessalit
# Processing Record 3 of set 7 | Farafangana
# Processing Record 4 of set 7 | Adrar
# Processing Record 5 of set 7 | Raudeberg
# Processing Record 6 of set 7 | Atambua
# Processing Record 7 of set 7 | Torrington
# Processing Record 8 of set 7 | Liku
# Processing Record 9 of set 7 | Raiganj
# Processing Record 10 of set 7 | Dingle
# Processing Record 11 of set 7 | Kutum
# Processing Record 12 of set 7 | Paamiut
# Processing Record 13 of set 7 | Bilma
# Processing Record 14 of set 7 | Lokosovo
# Processing Record 15 of set 7 | Mahibadhoo
# Processing Record 16 of set 7 | Phan Thiet
# Processing Record 17 of set 7 | Saint-Felicien
# Processing Record 18 of set 7 | Igrim
# Processing Record 19 of set 7 | Turayf
# Processing Record 20 of set 7 | Kiunga
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 21 of set 7 | Terney
# Processing Record 22 of set 7 | The Pas
# Processing Record 23 of set 7 | Stepnyak
# Processing Record 24 of set 7 | Iqaluit
# City not found. Skipping...
# Processing Record 25 of set 7 | Bermeo
# City not found. Skipping...
# Processing Record 26 of set 7 | Mecca
# Processing Record 27 of set 7 | Luderitz
# Processing Record 28 of set 7 | Baracoa
# Processing Record 29 of set 7 | Pavlovka
# Processing Record 30 of set 7 | Rabagani
# Processing Record 31 of set 7 | Vallenar
# Processing Record 32 of set 7 | Muisne
# Processing Record 33 of set 7 | Christchurch
# Processing Record 34 of set 7 | Petropavlovsk-Kamchatskiy
# Processing Record 35 of set 7 | Monrovia
# Processing Record 36 of set 7 | Maniitsoq
# Processing Record 37 of set 7 | Bom Jesus
# Processing Record 38 of set 7 | Mount Gambier
# Processing Record 39 of set 7 | Padang
# Processing Record 40 of set 7 | Suifenhe
# Processing Record 41 of set 7 | Yeppoon
# Processing Record 42 of set 7 | Tado
# Processing Record 43 of set 7 | Duran
# Processing Record 44 of set 7 | Labuhan
# Processing Record 45 of set 7 | Rovaniemi
# Processing Record 46 of set 7 | Mnogovershinnyy
# Processing Record 47 of set 7 | Atherton
# Processing Record 48 of set 7 | Amvrosiyivka
# Processing Record 49 of set 7 | Juneau
# Processing Record 50 of set 7 | Palmer
# Processing Record 1 of set 8 | Valleyview
# Processing Record 2 of set 8 | Villa Carlos Paz
# City not found. Skipping...
# Processing Record 3 of set 8 | Chingirlau
# Processing Record 4 of set 8 | Cayenne
# Processing Record 5 of set 8 | Bandarbeyla
# Processing Record 6 of set 8 | Lakes Entrance
# Processing Record 7 of set 8 | Requena
# Processing Record 8 of set 8 | Caravelas
# Processing Record 9 of set 8 | Mount Isa
# Processing Record 10 of set 8 | Zapolyarnyy
# Processing Record 11 of set 8 | Douentza
# Processing Record 12 of set 8 | Marienburg
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 24 of set 9 | Constitucion
# Processing Record 25 of set 9 | Luxor
# Processing Record 26 of set 9 | Broken Hill
# Processing Record 27 of set 9 | Pontypool
# Processing Record 28 of set 9 | Sitka
# Processing Record 29 of set 9 | San Ramon
# City not found. Skipping...
# Processing Record 30 of set 9 | Nantucket
# Processing Record 31 of set 9 | Pravda
# Processing Record 32 of set 9 | Nhulunbuy
# Processing Record 33 of set 9 | Bodden Town
# City not found. Skipping...
# Processing Record 34 of set 9 | Mokhsogollokh
# Processing Record 35 of set 9 | Buchanan
# Processing Record 36 of set 9 | Daru
# Processing Record 37 of set 9 | Kataysk
# Processing Record 38 of set 9 | Grand-Santi
# Processing Record 39 of set 9 | Lock Haven
# Processing Record 40 of set 9 | La Paz
# Processing Record 41 of set 9 | Rio Piracicaba
# Processing Record 42 of set 9 | Morristown
# Processing Record 43 of set 9 | Puerto Leguizamo
# Processing Record 44 of set 9 | Sola
# City not found. Skipping...
# Processing Record 45 of set 9 | Bachaquero
# City not found. Skipping...
# Processing Record 46 of set 9 | Matamoros
# Processing Record 47 of set 9 | Areal
# Processing Record 48 of set 9 | Aktau
# City not found. Skipping...
# Processing Record 49 of set 9 | Chilliwack
# Processing Record 50 of set 9 | Saint Paul
# Processing Record 1 of set 10 | Luanda
# City not found. Skipping...
# Processing Record 2 of set 10 | Santa Cruz
# Processing Record 3 of set 10 | Horki
# Processing Record 4 of set 10 | Grand Gaube
# City not found. Skipping...
# Processing Record 5 of set 10 | Msanga
# Processing Record 6 of set 10 | Qabaqcol
# Processing Record 7 of set 10 | Yulara
# Processing Record 8 of set 10 | Pasco
# Processing Record 9 of set 10 | Matagami
# Processing Record 10 of set 10 | Ayan
# Processing Record 11 of set 10 | Adelaide
# Processing Record 12 of set 10 | Aykhal
# Processing Record 13 of set 10 | Marystown
# Processing Record 14 of set 10 | Ponta Delgada
# Processing Record 15 of set 10 | Mattawa
# Processing Record 16 of set 10 | Souillac
# Processing Record 17 of set 10 | Tazovskiy
# Processing Record 18 of set 10 | Lazaro Cardenas
# City not found. Skipping...
# Processing Record 19 of set 10 | Omsukchan
# Processing Record 20 of set 10 | Yumen
# Processing Record 21 of set 10 | Jardim
# Processing Record 22 of set 10 | Ranikhet
# Processing Record 23 of set 10 | Edea
# Processing Record 24 of set 10 | Bibiani
# Processing Record 25 of set 10 | Emba
# Processing Record 26 of set 10 | Geraldton
# Processing Record 27 of set 10 | Pecos
# Processing Record 28 of set 10 | Tibati
# Processing Record 29 of set 10 | Andilamena
# Processing Record 30 of set 10 | Nyuksenitsa
# Processing Record 31 of set 10 | Jalu
# Processing Record 32 of set 10 | Novo Aripuana
# Processing Record 33 of set 10 | The Valley
# Processing Record 34 of set 10 | Cap Malheureux
# Processing Record 35 of set 10 | Berlevag
# Processing Record 36 of set 10 | Sao Felix Do Xingu
# Processing Record 37 of set 10 | Halifax
# Processing Record 38 of set 10 | Isangel
# Processing Record 39 of set 10 | Glace Bay
# Processing Record 40 of set 10 | Vostok
# City not found. Skipping...
# Processing Record 41 of set 10 | Skjervoy
# Processing Record 42 of set 10 | Pauini
# Processing Record 43 of set 10 | Youkounkoun
# Processing Record 44 of set 10 | Hualmay
# Processing Record 45 of set 10 | Erzin
# City not found. Skipping...
# Processing Record 46 of set 10 | Karpathos
# Processing Record 47 of set 10 | Nassau
# Processing Record 48 of set 10 | Tura
# Processing Record 49 of set 10 | Luancheng
# Processing Record 50 of set 10 | Tsalka
# Processing Record 1 of set 11 | Torbay
# Processing Record 2 of set 11 | Narrabri
# City not found. Skipping...
# Processing Record 3 of set 11 | Ancud
# Processing Record 4 of set 11 | Rocha
# Processing Record 5 of set 11 | Sembakung
# Processing Record 6 of set 11 | Kupang
# Processing Record 7 of set 11 | Vidim
# Processing Record 8 of set 11 | Santa Barbara
# City not found. Skipping...
# Processing Record 9 of set 11 | Karratha
# City not found. Skipping...
# Processing Record 10 of set 11 | Sabinopolis
# Processing Record 11 of set 11 | Tokmak
# Processing Record 12 of set 11 | Gibara
# Processing Record 13 of set 11 | Kijang
# Processing Record 14 of set 11 | Vaitape
# Processing Record 15 of set 11 | Monki
# Processing Record 16 of set 11 | Kaoma
# Processing Record 17 of set 11 | Curitibanos
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 18 of set 11 | Port-Gentil
# City not found. Skipping...
# Processing Record 19 of set 11 | Port Pirie
# Processing Record 20 of set 11 | Valdivia
# Processing Record 21 of set 11 | Kargasok
# Processing Record 22 of set 11 | Nioaque
# Processing Record 23 of set 11 | Zyryanka
# Processing Record 24 of set 11 | Collierville
# Processing Record 25 of set 11 | Guerrero
# Processing Record 26 of set 11 | Husavik
# Processing Record 27 of set 11 | Dubinino
# Processing Record 28 of set 11 | Singkang
# Processing Record 29 of set 11 | Kenai
# Processing Record 30 of set 11 | Mount Pleasant
# Processing Record 31 of set 11 | Louis Trichardt
# Processing Record 32 of set 11 | Hobyo
# Processing Record 33 of set 11 | Sterling
# Processing Record 34 of set 11 | Fiche
# Processing Record 35 of set 11 | Taree
# Processing Record 36 of set 11 | Alta Floresta
# Processing Record 37 of set 11 | Illapel
# Processing Record 38 of set 11 | Vagur
# Processing Record 39 of set 11 | Socorro
# Processing Record 40 of set 11 | Belyy Yar
# Processing Record 41 of set 11 | Rio Gallegos
# Processing Record 42 of set 11 | Qinhuangdao
# Processing Record 43 of set 11 | Gbadolite
# Processing Record 44 of set 11 | Axim
# Processing Record 45 of set 11 | Mbandaka
# Processing Record 46 of set 11 | Inhambane
# Processing Record 47 of set 11 | Awbari
# City not found. Skipping...
# Processing Record 48 of set 11 | Bedele
# Processing Record 49 of set 11 | Benguela
# Processing Record 50 of set 11 | Gidole
# Processing Record 1 of set 12 | Saint-Augustin
# Processing Record 2 of set 12 | Bathsheba
# Processing Record 3 of set 12 | Sioux Falls
# Processing Record 4 of set 12 | Rabaul
# Processing Record 5 of set 12 | Malinovoye Ozero
# Processing Record 6 of set 12 | Kodoli
# Processing Record 7 of set 12 | Lagoa
# Processing Record 8 of set 12 | Kimry
# Processing Record 9 of set 12 | Weiser
# Processing Record 10 of set 12 | Takestan
# Processing Record 11 of set 12 | Kem
# Processing Record 12 of set 12 | Sant Feliu De Guixols
# Processing Record 13 of set 12 | Billings
# Processing Record 14 of set 12 | Kroonstad
# Processing Record 15 of set 12 | Buin
# Processing Record 16 of set 12 | Kodala
# Processing Record 17 of set 12 | La Mana
# City not found. Skipping...
# Processing Record 18 of set 12 | Biak
# Processing Record 19 of set 12 | Vung Tau
# Processing Record 20 of set 12 | Vilyuysk
# Processing Record 21 of set 12 | Concepcion Del Uruguay
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 22 of set 12 | Baishishan
# Processing Record 23 of set 12 | Nea Peramos
# Processing Record 24 of set 12 | Channel-Port Aux Basques
# Processing Record 25 of set 12 | Warrnambool
# Processing Record 26 of set 12 | Lata
# Processing Record 27 of set 12 | Necochea
# Processing Record 28 of set 12 | Mao
# Processing Record 29 of set 12 | Ulaangom
# Processing Record 30 of set 12 | Lixourion
# Processing Record 31 of set 12 | Ifanadiana
# Processing Record 32 of set 12 | Sistranda
# City not found. Skipping...
# Processing Record 33 of set 12 | Winton
# Processing Record 34 of set 12 | Oranjemund
# Processing Record 35 of set 12 | Novyy Urgal
# Processing Record 36 of set 12 | Narasannapeta
# Processing Record 37 of set 12 | Alugan
# Processing Record 38 of set 12 | Mayo
# Processing Record 39 of set 12 | Sao Gabriel Da Cachoeira
# Processing Record 40 of set 12 | Zambezi
# Processing Record 41 of set 12 | Kodinsk
# Processing Record 42 of set 12 | Srednekolymsk
# Processing Record 43 of set 12 | Pantai Remis
# Processing Record 44 of set 12 | Oltu
# Processing Record 45 of set 12 | Inirida
# City not found. Skipping...
# Processing Record 46 of set 12 | Luganville
# Processing Record 47 of set 12 | Alanya
# Processing Record 48 of set 12 | Harbin
# Processing Record 49 of set 12 | Dawson Creek
# Processing Record 50 of set 12 | La Macarena
# Processing Record 1 of set 13 | Pisco
# Processing Record 2 of set 13 | Gushikawa
# Processing Record 3 of set 13 | Dumbea
# Processing Record 4 of set 13 | Beringovskiy
# Processing Record 5 of set 13 | Kudahuvadhoo
# Processing Record 6 of set 13 | Awka
# Processing Record 7 of set 13 | Kobryn
# Processing Record 8 of set 13 | La Rioja
# Processing Record 9 of set 13 | Las Vegas
# Processing Record 10 of set 13 | Port Hardy
# Processing Record 11 of set 13 | Nisia Floresta
# City not found. Skipping...
# Processing Record 12 of set 13 | Gerash
# City not found. Skipping...
# Processing Record 13 of set 13 | Altamira
# Processing Record 14 of set 13 | Les Cayes
# Processing Record 15 of set 13 | Tupik
# City not found. Skipping...
# Processing Record 16 of set 13 | Mount Barker
# Processing Record 17 of set 13 | Ayorou
# Processing Record 18 of set 13 | Podor
# Processing Record 19 of set 13 | Chokurdakh
# Processing Record 20 of set 13 | Abeche
# Processing Record 21 of set 13 | Sorland
# Processing Record 22 of set 13 | Mayumba
# Processing Record 23 of set 13 | Caborca
# Processing Record 24 of set 13 | Pavlovsk
# Processing Record 25 of set 13 | Springbok
# City not found. Skipping...
# Processing Record 26 of set 13 | Aosta
# City not found. Skipping...
# Processing Record 27 of set 13 | Auki
# Processing Record 28 of set 13 | Realeza
# City not found. Skipping...
# Processing Record 29 of set 13 | Beatrice
# Processing Record 30 of set 13 | Emerald
# Processing Record 31 of set 13 | Charleston
# Processing Record 32 of set 13 | Granados
# City not found. Skipping...
# Processing Record 33 of set 13 | Farmington
# Processing Record 34 of set 13 | Paungde
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 35 of set 13 | Toyota
# Processing Record 36 of set 13 | Tapiramuta
# Processing Record 37 of set 13 | Portland
# Processing Record 38 of set 13 | Saint Anthony
# Processing Record 39 of set 13 | Lanigan
# Processing Record 40 of set 13 | Warrensburg
# Processing Record 41 of set 13 | Gainesville
# Processing Record 42 of set 13 | Ust-Barguzin
# Processing Record 43 of set 13 | Filadelfia
# Processing Record 44 of set 13 | Nakhon Thai
# City not found. Skipping...
# Processing Record 45 of set 13 | Winneba
# Processing Record 46 of set 13 | Svobodnyy
# Processing Record 47 of set 13 | Sakaiminato
# Processing Record 48 of set 13 | Kodinar
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 49 of set 13 | Taicheng
# Processing Record 50 of set 13 | Leningradskiy
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 1 of set 14 | Castelo Do Piaui
# Processing Record 2 of set 14 | Guilin
# Processing Record 3 of set 14 | Yerbogachen
# Processing Record 4 of set 14 | Diban
# Processing Record 5 of set 14 | Mizdah
# Processing Record 6 of set 14 | Buala
# Processing Record 7 of set 14 | Clyde
# Processing Record 8 of set 14 | Hudson Bay
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Create summary of desired weather details 
summary = ["name", "clouds.all","sys.country","dt","main.humidity","coord.lat","coord.lon","main.temp_max","wind.speed"]
# Create an empty list to append all summary details for each city
city_weather = []

print("Beginning Data Retrieval")
print("-----------------------------")
for each_set in cities_set:
    for city in each_set:
        try:
            set_num = cities_set.index(each_set) + 1
            record_num = each_set.index(city) + 1
            weather_info = owm.get_current(city, **settings)(*summary)
            city_weather.append(weather_info)
            print(f"Processing Record {record_num} of set {set_num} | {city}")
        except :
            print ("City not found. Skipping...")
print("-----------------------------")
print("Data Retrieval Complete  ")  
print("-----------------------------")

# %% [markdown]
# ## Convert Raw Data to DataFrame

# %%
# Create header for CSV file for clean column names
header = [("City","Cloudiness","Country","Date","Humidity","Lat","Lng","Max Temp","Wind Speed")]
# Add header to city_weather's list of tuples
city_weather_data = header + city_weather

# Write and export the city_weather_date into a .csv file in the output_data folder
with open(output_data_file, "w", newline = "") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerows(city_weather_data)

# %%
# Read the weather data from the output_date_file
weather_data = pd.read_csv(output_data_file)
# Set weather_date as Panda dataframe
weather_df = pd.DataFrame(weather_data)
# Check how many entries are in the dataframe
weather_df.count()

# If there are fewer entries in the Country column, it is because the count 
# function is excluding Namibia since its country code is NA
# Out:
# City          658
# Cloudiness    658
# Country       654
# Date          658
# Humidity      658
# Lat           658
# Lng           658
# Max Temp      658
# Wind Speed    658
# dtype: int64

# %%
# Print first five entries in the dataframe
weather_df.head(5)
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat    Lng  \
# 0         Senekal           0      ZA  1562533875        77 -28.32  27.62
# 1         Miramar          40      CR  1562533875        51  10.09 -84.73
# 2         Ushuaia           0      AR  1562533662        92 -54.81 -68.31
# 3  Saint-Philippe           1      CA  1562533875        29  45.36 -73.48
# 4       Cape Town          40      ZA  1562533769        87 -33.93  18.42
#
#    Max Temp  Wind Speed
# 0     41.88        5.86
# 1     84.20        5.82
# 2     35.60        4.70
# 3     79.00        8.21
# 4     57.99       11.41

# %% [markdown]
# ## Plotting the Data

# %%
# Get date of analysis from first element of the dataframe
# The date portion from the Date column is the same for all entries - only the time changes as it corresponds to retrival time
date = time.strftime("%m/%d/%Y",time.localtime(weather_df["Date"][0]))

# %% [markdown]
# ### Latitude vs. Temperature Plot

# %%
# Set-up the plot and the figure size
fig,ax = plt.subplots(figsize=(7,4))
# Create scatter plot using latitude as the x-axis and maximum temperature as the y-axis
ax.scatter(weather_df["Lat"],weather_df["Max Temp"],color='orchid',edgecolors="black")

# Label the equator line for better visibility
equator = ax.axvline(x=0,lw=0.75,color="blue",label="Equator")
ax.legend(handles=[equator],loc="best")

# Title the plot
ax.set_title(f"City Latitude vs. Max Temperature ({date})")
# Label both of the axis accordingly
ax.set_xlabel("Latitude")
ax.set_ylabel("Max Temperature (F)")
# Add gridlines
ax.grid()

# Use tight_layout to automatically adjust params
plt.tight_layout()
# Save the figure as .png
plt.savefig('Latitude_v_Max_Temp.png')
# Display the figure
plt.show()

# %% [markdown]
# ### Latitude vs. Humidity Plot

# %%
# Set-up the plot and the figure size
fig,ax = plt.subplots(figsize=(7,4))
# Create scatter plot using latitude as the x-axis and humidity % as the y-axis
ax.scatter(weather_df["Lat"],weather_df["Humidity"],color='lemonchiffon',edgecolors="black")
# Set y-limit to ensure all percentages range from 0 to 100 (with +/- 5 for plot clarity)
ax.set_ylim(-5,105)

# Label the equator line for better visibility
equator = ax.axvline(x=0,lw=0.75,color="blue",label="Equator")
ax.legend(handles=[equator],loc="best")

# Title the plot
ax.set_title(f"City Latitude vs. Humidity ({date})")
# Label both of the axis accordingly
ax.set_xlabel("Latitude")
ax.set_ylabel("Humidity (%)")
# Add gridlines
ax.grid()

# Use tight_layout to automatically adjust params
plt.tight_layout()
# Save the figure as .png
plt.savefig('Latitude_v_Humidity.png')
# Display the figure
plt.show()

# %% [markdown]
# ### Latitude vs. Cloudiness Plot

# %%
# Set-up the plot and the figure size
fig,ax = plt.subplots(figsize=(7,4))
# Create scatter plot using latitude as the x-axis and cloudiness % as the y-axis
ax.scatter(weather_df["Lat"],weather_df["Cloudiness"],color='lightseagreen',edgecolors="black")
# Set y-limit to ensure all percentages range from 0 to 100 (with +/- 5 for plot clarity)
ax.set_ylim(-5,105)

# Label the equator line for better visibility
equator = ax.axvline(x=0,lw=0.75,color="blue",label="Equator")
ax.legend(handles=[equator],loc="best")

# Title the plot
ax.set_title(f"City Latitude vs. Cloudiness ({date})")
# Label both of the axis accordingly
ax.set_xlabel("Latitude")
ax.set_ylabel("Cloudiness (%)")
# Add gridlines
ax.grid()

# Use tight_layout to automatically adjust params
plt.tight_layout()
# Save the figure as .png
plt.savefig('Latitude_v_Cloudiness.png')
# Display the figure
plt.show()

# %% [markdown]
# ### Latitude vs. Wind Speed Plot

# %%
# Set-up the plot and the figure size
fig,ax = plt.subplots(figsize=(7,4))
# Create scatter plot using latitude as the x-axis and wind speed in mph as the y-axis
ax.scatter(weather_df["Lat"],weather_df["Wind Speed"],color='lightcoral',edgecolors="black")

# Label the equator line for better visibility
equator = ax.axvline(x=0,lw=0.75,color="blue",label="Equator")
ax.legend(handles=[equator],loc="best")

# Title the plot
ax.set_title(f"City Latitude vs. Wind Speed ({date})")
# Label both of the axis accordingly
ax.set_xlabel("Latitude")
ax.set_ylabel("Wind Speed (mph)")
# Add gridlines
ax.grid()

# Use tight_layout to automatically adjust params
plt.tight_layout()
# Save the figure as .png
plt.savefig('Latitude_v_Wind_Speed.png')
# Display the figure
plt.show()
